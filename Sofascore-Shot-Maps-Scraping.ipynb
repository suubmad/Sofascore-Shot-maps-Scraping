# %%
import requests

from bs4 import BeautifulSoup

# %%
response = requests.get(
    'https://www.sofascore.com/alanyaspor-yilport-samsunspor/dlbsmCc#id:11450177',
    headers={
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
    }
)

# %%
response.status_code
# Out:
# 200

# %%
soup =  BeautifulSoup(response.text, 'html.parser')

# %%
soup.select('g[BeautifulSoup]')
# Out:
# []

# %%
import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"a8e526b3dc"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11450177/shotmap', headers=headers)

# %%
headers['If-Modified-Since'] = 'Tue, 06 Feb 2024 00:00:00 GMT'

# %%
response = requests.get('https://api.sofascore.com/api/v1/event/11450177/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
shots_Alanyaspor = response.json()

# %%
shots_Alanyaspor
# Out:
# {'shotmap': [{'player': {'name': 'Marius Mouandilmadji',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'marius-mouandilmadji',
#     'shortName': 'M. Mouandilmadji',
#     'position': 'F',
#     'jerseyNumber': '9',
#     'userCount': 361,
#     'id': 943593},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 11, 'y': 48.3, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 40.3, 'z': 15.3},
#    'xg': 0.11627905070782,
#    'id': 2418002,
#    'time': 90,
#    'addedTime': 8,
#    'timeSeconds': 5829,
#    'draw': {'start': {'x': 48.3, 'y': 11},
#     'end': {'x': 59.7, 'y': 0},
#     'goal': {'x': 59.7, 'y': 84.7}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 471,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Marius Mouandilmadji',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'marius-mouandilmadji',
# ...
